# %%
hallwayList = []
for x in ['00001','00002','00003','00004','00005','00006','00007','00008','00009','00010']:
    hallwayList.append(pd.read_csv(f'data/train/{x}/video_hallway.csv'))

# %%
kitchenList = []
for x in ['00001','00002','00003','00004','00005','00006','00007','00008','00009','00010']:
    kitchenList.append(pd.read_csv(f'data/train/{x}/video_kitchen.csv'))

# %%
livingRoomList = []
for x in ['00001','00002','00003','00004','00005','00006','00007','00008','00009','00010']:
    livingRoomList.append(pd.read_csv(f'data/train/{x}/video_living_room.csv'))

# %%
for df in hallwayList:
    print(df.isna().sum())
# Out:
# t              0
# centre_2d_x    0
# centre_2d_y    0
# bb_2d_br_x     0
# bb_2d_br_y     0
# bb_2d_tl_x     0
# bb_2d_tl_y     0
# centre_3d_x    0
# centre_3d_y    0
# centre_3d_z    0
# bb_3d_brb_x    0
# bb_3d_brb_y    0
# bb_3d_brb_z    0
# bb_3d_flt_x    0
# bb_3d_flt_y    0
# bb_3d_flt_z    0
# dtype: int64
# t              0
# centre_2d_x    0
# centre_2d_y    0
# bb_2d_br_x     0
# bb_2d_br_y     0
# bb_2d_tl_x     0
# bb_2d_tl_y     0
# centre_3d_x    0
# centre_3d_y    0
# centre_3d_z    0
# bb_3d_brb_x    0
# bb_3d_brb_y    0
# bb_3d_brb_z    0
# bb_3d_flt_x    0
# bb_3d_flt_y    0
# bb_3d_flt_z    0
# dtype: int64
# t              0
# centre_2d_x    0
# centre_2d_y    0
# bb_2d_br_x     0
# bb_2d_br_y     0
# bb_2d_tl_x     0
# bb_2d_tl_y     0
# centre_3d_x    0
# centre_3d_y    0
# centre_3d_z    0
# bb_3d_brb_x    0
# bb_3d_brb_y    0
# bb_3d_brb_z    0
# bb_3d_flt_x    0
# bb_3d_flt_y    0
# bb_3d_flt_z    0
# dtype: int64
# t              0
# centre_2d_x    0
# ...

# %%
for df in kitchenList:
    print(df.isna().sum())
# Out:
# t              0
# centre_2d_x    0
# centre_2d_y    0
# bb_2d_br_x     0
# bb_2d_br_y     0
# bb_2d_tl_x     0
# bb_2d_tl_y     0
# centre_3d_x    0
# centre_3d_y    0
# centre_3d_z    0
# bb_3d_brb_x    0
# bb_3d_brb_y    0
# bb_3d_brb_z    0
# bb_3d_flt_x    0
# bb_3d_flt_y    0
# bb_3d_flt_z    0
# dtype: int64

# %%
for df in livingRoomList:
    print(df.isna().sum())
# Out:
# t              0
# centre_2d_x    0
# centre_2d_y    0
# bb_2d_br_x     0
# bb_2d_br_y     0
# bb_2d_tl_x     0
# bb_2d_tl_y     0
# centre_3d_x    0
# centre_3d_y    0
# centre_3d_z    0
# bb_3d_brb_x    0
# bb_3d_brb_y    0
# bb_3d_brb_z    0
# bb_3d_flt_x    0
# bb_3d_flt_y    0
# bb_3d_flt_z    0
# dtype: int64
# t              0
# centre_2d_x    0
# centre_2d_y    0
# bb_2d_br_x     0
# bb_2d_br_y     0
# bb_2d_tl_x     0
# bb_2d_tl_y     0
# centre_3d_x    0
# centre_3d_y    0
# centre_3d_z    0
# bb_3d_brb_x    0
# bb_3d_brb_y    0
# bb_3d_brb_z    0
# bb_3d_flt_x    0
# bb_3d_flt_y    0
# bb_3d_flt_z    0
# dtype: int64
# t              0
# centre_2d_x    0
# centre_2d_y    0
# bb_2d_br_x     0
# bb_2d_br_y     0
# bb_2d_tl_x     0
# bb_2d_tl_y     0
# centre_3d_x    0
# centre_3d_y    0
# centre_3d_z    0
# bb_3d_brb_x    0
# bb_3d_brb_y    0
# bb_3d_brb_z    0
# bb_3d_flt_x    0
# bb_3d_flt_y    0
# bb_3d_flt_z    0
# dtype: int64
# t              0
# centre_2d_x    0
# ...
